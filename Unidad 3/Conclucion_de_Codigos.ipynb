# %% [markdown]
# <a href="https://colab.research.google.com/github/JulioDuarteE/Simulacion/blob/main/Unidad%203/Conclucion_de_Codigos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Unidad 3
# ##Conclucion de codigos
# ###Maestro: Jose Gabriel Rodriguez Rivas
# ###Alumno: Duarte Espinoza Jose Julio

# %% [markdown]
# 1. 📦 Distribución Binomial
# Contexto: Satisfacción de pedidos diarios en distribuidor electrónico.
#
# Parámetros:
#
# Pedidos por día: 20
#
# Probabilidad de éxito: 70%
#
# Días simulados: 7
#
# Resultados típicos:
#
# Pedidos satisfechos por día: Ej. [14, 15, 13, 16, 12, 14, 15]
#
# Media esperada: ~14 pedidos/día
#
# Variabilidad observada: ±3 pedidos respecto a la media
#
# 🔎 Análisis:
#
# El 70% de éxito se traduce en ~14 pedidos satisfechos diarios en promedio.
#
# La variabilidad natural muestra días con hasta 17 pedidos exitosos y otros con solo 12.
#
# ✅ Beneficios:
#
# Gestión de inventario: Previsión de stock necesario para cubrir la demanda.
#
# Planificación de personal: Asignación de recursos según días de mayor carga.
#
# Reducción de pérdidas: Minimiza pedidos no cumplidos por falta de stock.
#
# 2. ⚡ Distribución Exponencial
# Contexto: Llegada de vehículos a estación de carga rápida (15 min promedio entre llegadas).
#
# Parámetros:
#
# Tasa de llegada: 1 vehículo cada 15 minutos.
#
# Período simulado: 12 horas (720 minutos).
#
# Resultados típicos:
#
# Vehículos simulados en 12 horas: ~45-50.
#
# Tiempo promedio entre llegadas: ~15 minutos.
#
# Eventos raros: Algunas esperas superan 45 minutos (cola larga típica de distribuciones exponenciales).
#
# 🔎 Análisis:
#
# Aunque el promedio es 15 minutos, el 5-10% de los casos pueden tener esperas >30 minutos.
#
# En horas pico, la acumulación de esperas largas puede generar congestión.
#
# ✅ Beneficios:
#
# Diseño de infraestructura: Determina número óptimo de cargadores para evitar colas.
#
# Alertas tempranas: Identifica momentos críticos que requieren personal adicional.
#
# Experiencia del usuario: Permite estimar y comunicar tiempos de espera realistas.
#
# 3. ⏳ Distribución LogNormal
# Contexto: Tiempos de espera en servicio técnico de tienda electrónica.
#
# Parámetros:
#
# Media: 10 minutos.
#
# Desviación estándar: 2 minutos.
#
# Clientes simulados: 50.
#
# Resultados típicos:
#
# Tiempo total acumulado: ~500 minutos (8.3 horas) para 50 clientes.
#
# Tiempo promedio: ~10 minutos, pero con algunos casos >20 minutos.
#
# Distribución asimétrica: La mayoría espera <12 minutos, pero unos pocos tienen esperas prolongadas.
#
# 🔎 Análisis:
#
# El 80% de los clientes espera menos de 12 minutos.
#
# El 5% puede experimentar esperas >18 minutos (clientes insatisfechos potenciales).
#
# ✅ Beneficios:
#
# Optimización de turnos: Agendar citas con buffers para evitar colas.
#
# Priorización: Atender primero a clientes con esperas potencialmente largas.
#
# Mejora continua: Identifica procesos que causan demoras excepcionales.
#
# 📌 Conclusiones Generales
# Modelado de escenarios reales:
#
# Las distribuciones aleatorias capturan la incertidumbre inherente a procesos de servicio.
#
# Ventajas operativas:
#
# Binomomial: Ideal para eventos discretos (éxito/fracaso).
#
# Exponencial: Modela tiempos entre eventos independientes.
#
# LogNormal: Útil cuando los datos tienen asimetría positiva (ej. tiempos de espera).
#
# Impacto empresarial:
#
# Reduce costos por sobre-dimensionamiento de recursos.
#
# Mejora la satisfacción del cliente mediante una gestión predictiva.
